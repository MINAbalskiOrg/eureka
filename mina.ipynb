# %% [markdown]
# # This notebooks:

# %%
with(open("drive/MyDrive/mina/shared/mina.ipynb")) as notebook:
  print(notebook.readlines())
# Out:
# ['{"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"provenance":[],"mount_file_id":"19HO7QIv320aoY4jJApedTTCTaOJnIsxD","authorship_tag":"ABX9TyO8taUyVvftt3xgLPWEjTst"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"markdown","source":["# This notebooks:"],"metadata":{"id":"eQcfQW_ZUWB8"}},{"cell_type":"code","execution_count":3,"metadata":{"id":"oKJHLsesTYno","colab":{"base_uri":"https://localhost:8080/"},"executionInfo":{"status":"ok","timestamp":1774615363455,"user_tz":-60,"elapsed":11,"user":{"displayName":"Adam Balski","userId":"16408807636933961592"}},"outputId":"a9582680-2c72-42fc-fb6c-2a383c0ef09c"},"outputs":[{"output_type":"stream","name":"stdout","text":["[\'{\\"nbformat\\":4,\\"nbformat_minor\\":0,\\"metadata\\":{\\"colab\\":{\\"provenance\\":[],\\"mount_file_id\\":\\"19HO7QIv320aoY4jJApedTTCTaOJnIsxD\\",\\"authorship_tag\\":\\"ABX9TyO8zgDRlDHhK/oRKJjaSBRA\\"},\\"kernelspec\\":{\\"name\\":\\"python3\
# ...
